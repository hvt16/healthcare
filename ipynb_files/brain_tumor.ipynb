# %%
import  pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
model=pickle.load(open('./models/model_bt.pkl','rb'))
# Out:
# c:\users\harsh\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py:315: UserWarning: Trying to unpickle estimator SVC from version 1.0.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
dec = {0:'No Tumor', 1:'Positive Tumor'}

# %%
img = cv2.imread('./datasets/pituitary_tumor/image(1).jpg',0)

# %%
img1 = cv2.resize(img, (200,200))
img1 = img1.reshape(1,-1)/255
p = model.predict(img1)
plt.title(dec[p[0]])
plt.imshow(img, cmap='gray')
plt.axis('off')
print(dec[p[0]])
# Out:
# Positive Tumor
